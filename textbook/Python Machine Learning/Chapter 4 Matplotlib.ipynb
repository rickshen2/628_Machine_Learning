# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

style.use("ggplot")


path = "C:\\Temp\\563_Data\\"
filename = "B4.csv"
df = pd.read_csv(path+filename)
print(df.head(5))

# plt.scatter(df.y, df.x1)
# sns.pairplot(df)
# sns.get_dataset_names()
# sns.lmplot(data=df,x=df.x1, y=df.y)
# Out:
#       y      x1   x2     x3     x4   x5  x6  x7  x8  x9
# 0  29.5  5.0208  1.0  3.531  1.500  2.0   7   4  62   0
# 1  27.9  4.5429  1.0  2.275  1.175  1.0   6   3  40   0
# 2  25.9  4.5573  1.0  4.050  1.232  1.0   6   3  54   0
# 3  29.9  5.0597  1.0  4.455  1.121  1.0   6   3  42   0
# 4  29.9  3.8910  1.0  4.455  0.988  1.0   6   3  56   0

# %%
sns.lmplot(data = df, x= 'x1', y = 'y')

# %%
# swarmplot for categorical scatterplot with nooverlapping points

sns.swarmplot(data = df, x = 'x2', y = 'y')
ax = plt.gca()
ax.set_title("Distribution")

plt.show()
